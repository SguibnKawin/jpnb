# %%
# !conda update -n base conda -y
# !conda install pytorch -y
# !conda install scikit-learn -y
# !conda install sympy -y
# !conda install scipy -y
# !conda install bs4 -y
# !conda install selenium -y
# !conda install numpy -y
# !conda install pandas -y
# !conda install opencv -y
# !conda install ggplot2 -y
# !conda install matplotlib -y
# !conda install tensorflow -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py38h497a2fe_1001         341 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     cffi-1.14.5                |   py38ha65f79e_0         227 KB  conda-forge
#     chardet-4.0.0              |   py38h578d9bd_1         199 KB  conda-forge
#     conda-4.10.1               |   py38h578d9bd_0         3.1 MB  conda-forge
#     conda-package-handling-1.7.3|   py38h497a2fe_0         927 KB  conda-forge
#     cryptography-3.4.7         |   py38ha5dfef3_0         1.1 MB  conda-forge
#     icu-68.1                   |       h58526e2_0        13.0 MB  conda-forge
#     ld_impl_linux-64-2.35.1    |       hea4e1c9_2         618 KB  conda-forge
#     libcurl-7.76.1             |       hc4aaa36_1         328 KB  conda-forge
#     libffi-3.3                 |       h58526e2_2          51 KB  conda-forge
#     libgcc-ng-9.3.0            |      h2828fa1_19         7.8 MB  conda-forge
#     libgomp-9.3.0              |      h2828fa1_19         376 KB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_0         808 KB  conda-forge
#     libsolv-0.7.18             |       h780b84a_0         439 KB  conda-forge
#     libssh2-1.9.0              |       ha56f1ee_6         226 KB  conda-forge
#     libstdcxx-ng-9.3.0         |      h6de172a_19         4.0 MB  conda-forge
#     libxml2-2.9.10             |       h72842e0_4         774 KB  conda-forge
#     pycosat-0.6.3              |py38h497a2fe_1006         107 KB  conda-forge
#     pyopenssl-20.0.1           |     pyhd8ed1ab_0          48 KB  conda-forge
#     pysocks-1.7.1              |   py38h578d9bd_3          27 KB  conda-forge
#     readline-8.1               |       h46c0cb4_0         295 KB  conda-forge
#     requests-2.25.1            |     pyhd3deb0d_0          51 KB  conda-forge
#     ruamel_yaml-0.15.80        |py38h497a2fe_1004         272 KB  conda-forge
#     setuptools-49.6.0          |   py38h578d9bd_3         929 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sqlite-3.35.5              |       h74cdb3f_0         1.4 MB  conda-forge
#     tk-8.6.10                  |       h21135ba_1         3.2 MB  conda-forge
#     tqdm-4.60.0                |     pyhd8ed1ab_0          79 KB  conda-forge
#     urllib3-1.26.4             |     pyhd8ed1ab_0          99 KB  conda-forge
#     wheel-0.36.2               |     pyhd3deb0d_0          31 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        41.0 MB
#
# The following packages will be UPDATED:
#
#   c-ares                                  1.17.1-h36c2ea0_0 --> 1.17.1-h7f98852_1
#   cffi                                1.14.4-py38ha65f79e_1 --> 1.14.5-py38ha65f79e_0
#   chardet                           3.0.4-py38h924ce5b_1008 --> 4.0.0-py38h578d9bd_1
#   conda                                4.9.2-py38h578d9bd_0 --> 4.10.1-py38h578d9bd_0
#   conda-package-han~                   1.7.2-py38h8df0ef7_0 --> 1.7.3-py38h497a2fe_0
#   cryptography                         3.2.1-py38h7699a38_0 --> 3.4.7-py38ha5dfef3_0
#   icu                                       67.1-he1b5a44_0 --> 68.1-h58526e2_0
#   ld_impl_linux-64                        2.35.1-hed1e6ac_0 --> 2.35.1-hea4e1c9_2
#   libcurl                                 7.71.1-hcdd3856_8 --> 7.76.1-hc4aaa36_1
#   libffi                                     3.3-h58526e2_1 --> 3.3-h58526e2_2
#   libgcc-ng                               9.3.0-h5dbcf3e_17 --> 9.3.0-h2828fa1_19
#   libgomp                                 9.3.0-h5dbcf3e_17 --> 9.3.0-h2828fa1_19
#   libnghttp2                              1.41.0-h8cfc5f6_2 --> 1.43.0-h812cca2_0
#   libsolv                                 0.7.16-h8b12597_0 --> 0.7.18-h780b84a_0
#   libssh2                                  1.9.0-hab1572f_5 --> 1.9.0-ha56f1ee_6
#   libstdcxx-ng                            9.3.0-h2ae2ef3_17 --> 9.3.0-h6de172a_19
#   libxml2                                 2.9.10-h68273f3_2 --> 2.9.10-h72842e0_4
#   pycosat                           0.6.3-py38h8df0ef7_1005 --> 0.6.3-py38h497a2fe_1006
#   pyopenssl                             20.0.0-pyhd8ed1ab_0 --> 20.0.1-pyhd8ed1ab_0
#   pysocks                              1.7.1-py38h924ce5b_2 --> 1.7.1-py38h578d9bd_3
#   readline                                   8.0-he28a2e2_2 --> 8.1-h46c0cb4_0
#   requests                              2.25.0-pyhd3deb0d_0 --> 2.25.1-pyhd3deb0d_0
#   ruamel_yaml                     0.15.80-py38h8df0ef7_1003 --> 0.15.80-py38h497a2fe_1004
#   setuptools                          49.6.0-py38h924ce5b_2 --> 49.6.0-py38h578d9bd_3
#   six                                   1.15.0-pyh9f0ad1d_0 --> 1.16.0-pyh6c4a22f_0
#   sqlite                                  3.34.0-h74cdb3f_0 --> 3.35.5-h74cdb3f_0
#   tqdm                                  4.54.1-pyhd8ed1ab_0 --> 4.60.0-pyhd8ed1ab_0
#   urllib3                                      1.25.11-py_0 --> 1.26.4-pyhd8ed1ab_0
#   wheel                                 0.36.1-pyhd3deb0d_0 --> 0.36.2-pyhd3deb0d_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.4.13-~ --> conda-forge::ca-certificates-2020.12.5-ha878542_0
#
# The following packages will be DOWNGRADED:
#
#   brotlipy                          0.7.0-py38h8df0ef7_1001 --> 0.7.0-py38h497a2fe_1001
#   tk                                      8.6.10-hed695b0_1 --> 8.6.10-h21135ba_1
#
#
#
# Downloading and Extracting Packages
# libsolv-0.7.18       | 439 KB    | ##################################### | 100%
# ca-certificates-2020 | 137 KB    | ##################################### | 100%
# libgomp-9.3.0        | 376 KB    | ##################################### | 100%
# ruamel_yaml-0.15.80  | 272 KB    | ##################################### | 100%
# cffi-1.14.5          | 227 KB    | ##################################### | 100%
# libcurl-7.76.1       | 328 KB    | ##################################### | 100%
# conda-package-handli | 927 KB    | ##################################### | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ##################################### | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ##################################### | 100%
# libnghttp2-1.43.0    | 808 KB    | ##################################### | 100%
# urllib3-1.26.4       | 99 KB     | ##################################### | 100%
# pycosat-0.6.3        | 107 KB    | ##################################### | 100%
# pyopenssl-20.0.1     | 48 KB     | ##################################### | 100%
# requests-2.25.1      | 51 KB     | ##################################### | 100%
# setuptools-49.6.0    | 929 KB    | ##################################### | 100%
# c-ares-1.17.1        | 109 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 341 KB    | ##################################### | 100%
# sqlite-3.35.5        | 1.4 MB    | ##################################### | 100%
# wheel-0.36.2         | 31 KB     | ##################################### | 100%
# libffi-3.3           | 51 KB     | ##################################### | 100%
# readline-8.1         | 295 KB    | ##################################### | 100%
# tk-8.6.10            | 3.2 MB    | ##################################### | 100%
# six-1.16.0           | 14 KB     | ##################################### | 100%
# tqdm-4.60.0          | 79 KB     | ##################################### | 100%
# conda-4.10.1         | 3.1 MB    | ##################################### | 100%
# ld_impl_linux-64-2.3 | 618 KB    | ##################################### | 100%
# libxml2-2.9.10       | 774 KB    | ##################################### | 100%
# cryptography-3.4.7   | 1.1 MB    | ##################################### | 100%
# icu-68.1             | 13.0 MB   | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# chardet-4.0.0        | 199 KB    | ##################################### | 100%
# libssh2-1.9.0        | 226 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     future-0.18.2              |   py37h89c1867_3         714 KB  conda-forge
#     libblas-3.9.0              |            8_mkl          12 KB  conda-forge
#     libcblas-3.9.0             |            8_mkl          11 KB  conda-forge
#     liblapack-3.9.0            |            8_mkl          11 KB  conda-forge
#     libprotobuf-3.15.8         |       h780b84a_0         2.5 MB  conda-forge
#     llvm-openmp-11.1.0         |       h4bd325d_1         4.7 MB  conda-forge
#     mkl-2020.4                 |     h726a3e6_304       215.6 MB  conda-forge
#     ninja-1.10.2               |       h4bd325d_0         2.4 MB  conda-forge
#     numpy-1.20.2               |   py37h038b26d_0         5.8 MB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     pytorch-1.8.0              |cpu_py37ha70c682_1        43.3 MB  conda-forge
#     sleef-3.5.1                |       h7f98852_1         1.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       278.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   future             conda-forge/linux-64::future-0.18.2-py37h89c1867_3
#   libblas            conda-forge/linux-64::libblas-3.9.0-8_mkl
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-8_mkl
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-8_mkl
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.15.8-h780b84a_0
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-11.1.0-h4bd325d_1
#   mkl                conda-forge/linux-64::mkl-2020.4-h726a3e6_304
#   ninja              conda-forge/linux-64::ninja-1.10.2-h4bd325d_0
#   numpy              conda-forge/linux-64::numpy-1.20.2-py37h038b26d_0
#   pytorch            conda-forge/linux-64::pytorch-1.8.0-cpu_py37ha70c682_1
#   sleef              conda-forge/linux-64::sleef-3.5.1-h7f98852_1
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1k-h7f98852_0
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-1_llvm
#
#
#
# Downloading and Extracting Packages
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# sleef-3.5.1          | 1.5 MB    | ##################################### | 100%
# mkl-2020.4           | 215.6 MB  | ##################################### | 100%
# openssl-1.1.1k       | 2.1 MB    | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# future-0.18.2        | 714 KB    | ##################################### | 100%
# numpy-1.20.2         | 5.8 MB    | ##################################### | 100%
# libprotobuf-3.15.8   | 2.5 MB    | ##################################### | 100%
# pytorch-1.8.0        | 43.3 MB   | ##################################### | 100%
# _openmp_mutex-4.5    | 5 KB      | ##################################### | 100%
# llvm-openmp-11.1.0   | 4.7 MB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# ninja-1.10.2         | 2.4 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.0.1               |     pyhd8ed1ab_0         206 KB  conda-forge
#     libgfortran-ng-9.3.0       |      hff62375_19          22 KB  conda-forge
#     libgfortran5-9.3.0         |      hff62375_19         2.0 MB  conda-forge
#     scikit-learn-0.24.2        |   py37h18a542f_0         7.5 MB  conda-forge
#     scipy-1.6.3                |   py37h29e03ee_0        20.5 MB  conda-forge
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          15 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        30.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.0.1-pyhd8ed1ab_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-hff62375_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-hff62375_19
#   scikit-learn       conda-forge/linux-64::scikit-learn-0.24.2-py37h18a542f_0
#   scipy              conda-forge/linux-64::scipy-1.6.3-py37h29e03ee_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#
#
#
# Downloading and Extracting Packages
# libgfortran5-9.3.0   | 2.0 MB    | ##################################### | 100%
# threadpoolctl-2.1.0  | 15 KB     | ##################################### | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ##################################### | 100%
# scikit-learn-0.24.2  | 7.5 MB    | ##################################### | 100%
# scipy-1.6.3          | 20.5 MB   | ##################################### | 100%
# joblib-1.0.1         | 206 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - sympy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gmpy2-2.1.0b1              |   py37hcb968a4_1         206 KB  conda-forge
#     mpc-1.1.0                  |    h04dde30_1009         105 KB  conda-forge
#     mpfr-4.0.2                 |       he80fd80_1         648 KB  conda-forge
#     mpmath-1.2.1               |     pyhd8ed1ab_0         437 KB  conda-forge
#     sympy-1.8                  |   py37h89c1867_0        11.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gmpy2              conda-forge/linux-64::gmpy2-2.1.0b1-py37hcb968a4_1
#   mpc                conda-forge/linux-64::mpc-1.1.0-h04dde30_1009
#   mpfr               conda-forge/linux-64::mpfr-4.0.2-he80fd80_1
#   mpmath             conda-forge/noarch::mpmath-1.2.1-pyhd8ed1ab_0
#   sympy              conda-forge/linux-64::sympy-1.8-py37h89c1867_0
#
#
#
# Downloading and Extracting Packages
# gmp-6.2.1            | 806 KB    | ##################################### | 100%
# sympy-1.8            | 11.1 MB   | ##################################### | 100%
# mpc-1.1.0            | 105 KB    | ##################################### | 100%
# gmpy2-2.1.0b1        | 206 KB    | ##################################### | 100%
# mpmath-1.2.1         | 437 KB    | ##################################### | 100%
# mpfr-4.0.2           | 648 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - bs4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          86 KB  conda-forge
#     bs4-4.9.3                  |                0           4 KB  conda-forge
#     soupsieve-2.0.1            |             py_1          30 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         120 KB
#
# The following NEW packages will be INSTALLED:
#
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.9.3-pyhb0f4dca_0
#   bs4                conda-forge/noarch::bs4-4.9.3-0
#   soupsieve          conda-forge/noarch::soupsieve-2.0.1-py_1
#
#
#
# Downloading and Extracting Packages
# soupsieve-2.0.1      | 30 KB     | ##################################### | 100%
# bs4-4.9.3            | 4 KB      | ##################################### | 100%
# beautifulsoup4-4.9.3 | 86 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     selenium-3.141.0           |py37h5e8e339_1002         870 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         870 KB
#
# The following NEW packages will be INSTALLED:
#
#   selenium           conda-forge/linux-64::selenium-3.141.0-py37h5e8e339_1002
#
#
#
# Downloading and Extracting Packages
# selenium-3.141.0     | 870 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.2.4               |   py37h219a48f_0        11.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             conda-forge/linux-64::pandas-1.2.4-py37h219a48f_0
#
#
#
# Downloading and Extracting Packages
# pandas-1.2.4         | 11.8 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     cairo-1.16.0               |    h18b612c_1001         1.5 MB  conda-forge
#     ffmpeg-4.0                 |       hcdf2ecd_0        53.3 MB  defaults
#     fontconfig-2.13.1          |    hba837de_1005         357 KB  conda-forge
#     freeglut-3.2.1             |       h9c3ff4c_2         161 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     glib-2.68.1                |       h9c3ff4c_0         442 KB  conda-forge
#     glib-tools-2.68.1          |       h9c3ff4c_0          86 KB  conda-forge
#     graphite2-1.3.13           |    h58526e2_1001         102 KB  conda-forge
#     harfbuzz-1.8.8             |       hffaf4a1_0         507 KB  defaults
#     hdf5-1.10.2                |       hc401514_3         4.8 MB  conda-forge
#     icu-58.2                   |    hf484d3e_1000        22.6 MB  conda-forge
#     jasper-2.0.14              |       ha77e612_2         1.2 MB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     libgfortran-3.0.0          |                1         281 KB  conda-forge
#     libglib-2.68.1             |       h3e27bee_0         3.1 MB  conda-forge
#     libglu-9.0.0               |    he1b5a44_1001         413 KB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     libopencv-3.4.2            |       hb342d67_1        21.8 MB  defaults
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libtiff-4.2.0              |       hdc55705_1         678 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libvpx-1.7.0               |       h439df22_0         1.2 MB  defaults
#     libwebp-base-1.2.0         |       h7f98852_2         815 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1003         395 KB  conda-forge
#     libxml2-2.9.10             |       hb55368b_3         1.2 MB  defaults
#     lz4-c-1.9.3                |       h9c3ff4c_0         179 KB  conda-forge
#     opencv-3.4.2               |   py37h6fd60c2_1          11 KB  defaults
#     pcre-8.44                  |       he1b5a44_0         261 KB  conda-forge
#     pixman-0.38.0              |    h516909a_1003         594 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     py-opencv-3.4.2            |   py37hb342d67_1         1.0 MB  defaults
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-inputproto-2.3.2      |    h7f98852_1002          19 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.7.0          |       h7f98852_0         923 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-libxi-1.7.10          |       h7f98852_0          46 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zstd-1.4.9                 |       ha95c52a_0         431 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       125.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   cairo              conda-forge/linux-64::cairo-1.16.0-h18b612c_1001
#   ffmpeg             pkgs/main/linux-64::ffmpeg-4.0-hcdf2ecd_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1005
#   freeglut           conda-forge/linux-64::freeglut-3.2.1-h9c3ff4c_2
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   glib               conda-forge/linux-64::glib-2.68.1-h9c3ff4c_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.68.1-h9c3ff4c_0
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h58526e2_1001
#   harfbuzz           pkgs/main/linux-64::harfbuzz-1.8.8-hffaf4a1_0
#   hdf5               conda-forge/linux-64::hdf5-1.10.2-hc401514_3
#   icu                conda-forge/linux-64::icu-58.2-hf484d3e_1000
#   jasper             conda-forge/linux-64::jasper-2.0.14-ha77e612_2
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   libgfortran        conda-forge/linux-64::libgfortran-3.0.0-1
#   libglib            conda-forge/linux-64::libglib-2.68.1-h3e27bee_0
#   libglu             conda-forge/linux-64::libglu-9.0.0-he1b5a44_1001
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libopencv          pkgs/main/linux-64::libopencv-3.4.2-hb342d67_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libtiff            conda-forge/linux-64::libtiff-4.2.0-hdc55705_1
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libvpx             pkgs/main/linux-64::libvpx-1.7.0-h439df22_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.0-h7f98852_2
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1003
#   libxml2            pkgs/main/linux-64::libxml2-2.9.10-hb55368b_3
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_0
#   opencv             pkgs/main/linux-64::opencv-3.4.2-py37h6fd60c2_1
#   pcre               conda-forge/linux-64::pcre-8.44-he1b5a44_0
#   pixman             conda-forge/linux-64::pixman-0.38.0-h516909a_1003
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   py-opencv          pkgs/main/linux-64::py-opencv-3.4.2-py37hb342d67_1
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-inputproto    conda-forge/linux-64::xorg-inputproto-2.3.2-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.0-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.7.10-h7f98852_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.4.9-ha95c52a_0
#
#
#
# Downloading and Extracting Packages
# libopencv-3.4.2      | 21.8 MB   | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# icu-58.2             | 22.6 MB   | ##################################### | 100%
# xorg-renderproto-0.1 | 9 KB      | ##################################### | 100%
# zstd-1.4.9           | 431 KB    | ##################################### | 100%
# freeglut-3.2.1       | 161 KB    | ##################################### | 100%
# xorg-fixesproto-5.0  | 9 KB      | ##################################### | 100%
# opencv-3.4.2         | 11 KB     | ##################################### | 100%
# glib-tools-2.68.1    | 86 KB     | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# cairo-1.16.0         | 1.5 MB    | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# lz4-c-1.9.3          | 179 KB    | ##################################### | 100%
# ffmpeg-4.0           | 53.3 MB   | ##################################### | 100%
# py-opencv-3.4.2      | 1.0 MB    | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# xorg-libxi-1.7.10    | 46 KB     | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# libvpx-1.7.0         | 1.2 MB    | ##################################### | 100%
# xorg-libxfixes-5.0.3 | 18 KB     | ##################################### | 100%
# libgfortran-3.0.0    | 281 KB    | ##################################### | 100%
# xorg-libice-1.0.10   | 58 KB     | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# libxcb-1.13          | 395 KB    | ##################################### | 100%
# hdf5-1.10.2          | 4.8 MB    | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# graphite2-1.3.13     | 102 KB    | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# libglu-9.0.0         | 413 KB    | ##################################### | 100%
# libxml2-2.9.10       | 1.2 MB    | ##################################### | 100%
# xorg-libx11-1.7.0    | 923 KB    | ##################################### | 100%
# fontconfig-2.13.1    | 357 KB    | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# harfbuzz-1.8.8       | 507 KB    | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# glib-2.68.1          | 442 KB    | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# xorg-inputproto-2.3. | 19 KB     | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# libglib-2.68.1       | 3.1 MB    | ##################################### | 100%
# xorg-libxrender-0.9. | 32 KB     | ##################################### | 100%
# pcre-8.44            | 261 KB    | ##################################### | 100%
# jasper-2.0.14        | 1.2 MB    | ##################################### | 100%
# libtiff-4.2.0        | 678 KB    | ##################################### | 100%
# libopus-1.3.1        | 255 KB    | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# pixman-0.38.0        | 594 KB    | ##################################### | 100%
# xorg-libsm-1.2.3     | 26 KB     | ##################################### | 100%
# libwebp-base-1.2.0   | 815 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - ggplot2
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     dbus-1.13.6                |       h48d8840_2         572 KB  conda-forge
#     expat-2.3.0                |       h9c3ff4c_0         168 KB  conda-forge
#     gst-plugins-base-1.14.0    |       hbbd80ab_1         4.8 MB  defaults
#     gstreamer-1.14.0           |       h28cd5cc_2         3.2 MB  defaults
#     kiwisolver-1.3.1           |   py37h2527ec5_1          78 KB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     matplotlib-3.4.1           |   py37h89c1867_0           7 KB  conda-forge
#     matplotlib-base-3.4.1      |   py37hdd32ed1_0         7.3 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openjpeg-2.4.0             |       hf7af979_0         525 KB  conda-forge
#     pillow-8.1.2               |   py37h4600e1f_1         688 KB  conda-forge
#     pyqt-5.9.2                 |   py37hcca6a23_4         5.7 MB  conda-forge
#     qt-5.9.7                   |       h5867ecd_1        68.5 MB  defaults
#     sip-4.19.8                 |   py37hf484d3e_0         274 KB  defaults
#     ------------------------------------------------------------
#                                            Total:        92.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   dbus               conda-forge/linux-64::dbus-1.13.6-h48d8840_2
#   expat              conda-forge/linux-64::expat-2.3.0-h9c3ff4c_0
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.0-hbbd80ab_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.0-h28cd5cc_2
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.3.1-py37h2527ec5_1
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.4.1-py37h89c1867_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.4.1-py37hdd32ed1_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hf7af979_0
#   pillow             conda-forge/linux-64::pillow-8.1.2-py37h4600e1f_1
#   pyqt               conda-forge/linux-64::pyqt-5.9.2-py37hcca6a23_4
#   qt                 pkgs/main/linux-64::qt-5.9.7-h5867ecd_1
#   sip                pkgs/main/linux-64::sip-4.19.8-py37hf484d3e_0
#
#
#
# Downloading and Extracting Packages
# dbus-1.13.6          | 572 KB    | ##################################### | 100%
# pillow-8.1.2         | 688 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 4.8 MB    | ##################################### | 100%
# gstreamer-1.14.0     | 3.2 MB    | ##################################### | 100%
# sip-4.19.8           | 274 KB    | ##################################### | 100%
# matplotlib-3.4.1     | 7 KB      | ##################################### | 100%
# qt-5.9.7             | 68.5 MB   | ##################################### | 100%
# olefile-0.46         | 32 KB     | ##################################### | 100%
# expat-2.3.0          | 168 KB    | ##################################### | 100%
# lcms2-2.12           | 443 KB    | ##################################### | 100%
# matplotlib-base-3.4. | 7.3 MB    | ##################################### | 100%
# openjpeg-2.4.0       | 525 KB    | ##################################### | 100%
# kiwisolver-1.3.1     | 78 KB     | ##################################### | 100%
# pyqt-5.9.2           | 5.7 MB    | ##################################### | 100%
# cycler-0.10.0        | 9 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-0.12.0             |     pyhd8ed1ab_0          96 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     gast-0.4.0                 |     pyh9f0ad1d_0          12 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpcio-1.37.1              |   py37hb27c1af_0         2.2 MB  conda-forge
#     h5py-2.8.0                 |py37h3010b51_1003         1.1 MB  conda-forge
#     keras-applications-1.0.8   |             py_1          30 KB  conda-forge
#     keras-preprocessing-1.1.2  |     pyhd8ed1ab_0          34 KB  conda-forge
#     markdown-3.3.4             |     pyhd8ed1ab_0          67 KB  conda-forge
#     protobuf-3.15.8            |   py37hcd2ae1e_0         334 KB  conda-forge
#     tensorboard-1.14.0         |           py37_0         3.2 MB  conda-forge
#     tensorflow-1.14.0          |       h4531e10_0          23 KB  conda-forge
#     tensorflow-base-1.14.0     |   py37h4531e10_0        87.6 MB  conda-forge
#     tensorflow-estimator-1.14.0|   py37h5ca1d4c_0         645 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     werkzeug-1.0.1             |     pyh9f0ad1d_0         239 KB  conda-forge
#     wrapt-1.12.1               |   py37h5e8e339_3          47 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        95.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            conda-forge/noarch::absl-py-0.12.0-pyhd8ed1ab_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   gast               conda-forge/noarch::gast-0.4.0-pyh9f0ad1d_0
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpcio             conda-forge/linux-64::grpcio-1.37.1-py37hb27c1af_0
#   h5py               conda-forge/linux-64::h5py-2.8.0-py37h3010b51_1003
#   keras-applications conda-forge/noarch::keras-applications-1.0.8-py_1
#   keras-preprocessi~ conda-forge/noarch::keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   markdown           conda-forge/noarch::markdown-3.3.4-pyhd8ed1ab_0
#   protobuf           conda-forge/linux-64::protobuf-3.15.8-py37hcd2ae1e_0
#   tensorboard        conda-forge/linux-64::tensorboard-1.14.0-py37_0
#   tensorflow         conda-forge/linux-64::tensorflow-1.14.0-h4531e10_0
#   tensorflow-base    conda-forge/linux-64::tensorflow-base-1.14.0-py37h4531e10_0
#   tensorflow-estima~ conda-forge/linux-64::tensorflow-estimator-1.14.0-py37h5ca1d4c_0
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#   werkzeug           conda-forge/noarch::werkzeug-1.0.1-pyh9f0ad1d_0
#   wrapt              conda-forge/linux-64::wrapt-1.12.1-py37h5e8e339_3
#
#
#
# Downloading and Extracting Packages
# tensorboard-1.14.0   | 3.2 MB    | ##################################### | 100%
# gast-0.4.0           | 12 KB     | ##################################### | 100%
# wrapt-1.12.1         | 47 KB     | ##################################### | 100%
# markdown-3.3.4       | 67 KB     | ##################################### | 100%
# grpcio-1.37.1        | 2.2 MB    | ##################################### | 100%
# tensorflow-estimator | 645 KB    | ##################################### | 100%
# keras-applications-1 | 30 KB     | ##################################### | 100%
# astor-0.8.1          | 25 KB     | ##################################### | 100%
# werkzeug-1.0.1       | 239 KB    | ##################################### | 100%
# google-pasta-0.2.0   | 42 KB     | ##################################### | 100%
# keras-preprocessing- | 34 KB     | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# absl-py-0.12.0       | 96 KB     | ##################################### | 100%
# tensorflow-base-1.14 | 87.6 MB   | ##################################### | 100%
# protobuf-3.15.8      | 334 KB    | ##################################### | 100%
# h5py-2.8.0           | 1.1 MB    | ##################################### | 100%
# tensorflow-1.14.0    | 23 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import numpy as np

# %%
a = np.array([[1,2,3,4,5],[9,8,7,6,5]])
a
# Out:
# array([[1, 2, 3, 4, 5],
#        [9, 8, 7, 6, 5]])
